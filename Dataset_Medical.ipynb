# %%
rpath = "/home/shubham/strial/qt-database-1.0.0/"

# %%
import os
import numpy as np

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %%
files = os.listdir(rpath)
files
# Out:
# ['sel16273.pu',
#  'sel871.pu0',
#  'sele0166.atr',
#  'sele0612.xws',
#  'sel306.qt1',
#  'sel14157.qt1',
#  'sel33.qt1',
#  'sel117.man',
#  'sele0303.pu',
#  'sele0203.dat',
#  'sele0121.atr',
#  'sele0509.pu1',
#  'sele0122.pu',
#  'sele0409.qt1',
#  'sele0112.q1c',
#  'sel36.hea-',
#  'sele0124.pu1',
#  'sele0107.hea',
#  'sele0409.atr',
#  'sel14157.hea-',
#  'sele0170.hea',
#  'sele0606.q1c',
#  'sel34.xws',
#  'sel38.hea',
#  'sele0405.xws',
#  'sele0126.xws',
#  'sel43.xws',
#  'sel117.q2c',
#  'sel307.atr',
#  'sel15814.hea-',
#  'sele0509.dat',
#  'sel16795.hea',
#  'sele0112.man',
#  'sel16795.q1c',
#  'sel16795.pu1',
#  'sel30.hea',
#  'sel116.q1c',
#  'sel16773.q1c',
#  'sele0124.q1c',
#  'sel32.hea',
#  'sel873.xws',
#  'sel310.man',
#  'sel46.hea-',
#  'sel16795.atr',
#  'sel51.hea-',
#  'sele0210.q1c',
#  'sel891.xws',
#  'sel49.pu1',
#  'sele0603.qt1',
#  'sele0112.pu',
#  'sele0303.qt1',
#  'sel35.hea-',
#  'sel44.dat',
#  'sel232.qt1',
#  'sel847.xws',
# ...

# %%
print(".dat" in files[7])

# datfiles = filter(files,".dat")
datfiles = [file for file in files if file.endswith("dat")]
# print (datfiles)
# Out:
# False

# %%
fpath = os.path.join(rpath,datfiles[2])
file1 = open(fpath,"rb")

rfile  = list(file1.read())
len(rfile)
# Out:
# 674979

# %%
rfile[:10]
# Out:
# [238, 15, 11, 238, 15, 11, 238, 15, 11, 238]

# %%
fpath = os.path.join(rpath,datfiles[2])
rand_one = np.fromfile(fpath,dtype="float64",count=)

rand_one.shape
plt.plot(rand_one,"ro")
# Out:
# /home/shubham/.local/lib/python3.7/site-packages/matplotlib/transforms.py:2832: RuntimeWarning: overflow encountered in double_scalars
#   elif vmax - vmin <= maxabsvalue * tiny:
# /home/shubham/.local/lib/python3.7/site-packages/matplotlib/axes/_base.py:2477: RuntimeWarning: overflow encountered in double_scalars
#   delta = (x1t - x0t) * margin
